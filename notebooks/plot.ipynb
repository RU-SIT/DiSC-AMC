# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.io as pio

# %%
# Set default template for a clean, paper-ready look
pio.templates.default = "plotly_white"

# Data from your table
data = {
    '# Bins': [5, 10, 20, 30],
    'Accuracy (%)': [45.50, 39.00, 38.00, 37.00]
}
df = pd.DataFrame(data)

# Define the style based on your example code (using 'PN Train' style)
main_color = 'rgba(31, 119, 180, 1)'  # Blue
bg_color = 'rgba(31, 119, 180, 0.3)' # Lighter, semi-transparent blue
marker_symbol = 'circle'

# Create the figure object
fig = go.Figure()

# Add the background trace (thick, semi-transparent line)
fig.add_trace(go.Scatter(
    x=df["# Bins"],
    y=df["Accuracy (%)"],
    mode='lines',
    line=dict(color=bg_color, width=12),
    hoverinfo='none' # Don't show hover info for the background line
))

# Add the foreground trace (thin line with markers)
fig.add_trace(go.Scatter(
    x=df["# Bins"],
    y=df["Accuracy (%)"],
    mode='lines+markers',
    name='Accuracy',
    line=dict(color=main_color, width=2),
    marker=dict(
        color=main_color,
        symbol=marker_symbol,
        size=22
    )
))

# Apply the detailed layout and styling from your example
fig.update_layout(
    title=dict(
        text='<b>Effect of Number of Bins on Accuracy</b>',
        x=0.5,
        font=dict(size=32)
    ),
    xaxis_title='<b># Bins</b>',
    yaxis_title='<b>Accuracy (%)</b>',
    font=dict(size=28, family="Arial, sans-serif"),
    showlegend=False,
    margin=dict(l=80, r=40, t=80, b=80),
    paper_bgcolor="white",
    plot_bgcolor="white",
)

# Style the X and Y axes
fig.update_xaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(size=26, weight='bold')
)
fig.update_yaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(size=26, weight='bold')
)

# Save the figure as a static image
fig.write_image("styled_bins_vs_accuracy.png", scale=3)

fig.show()

# %%
# Set default template for a clean, paper-ready look
pio.templates.default = "plotly_white"

# Data from your table, focusing on the consistent "# Bins = 5" experiment
data = {
    'top-k': [2, 3, 4, 5, 6, 10],
    '# Tokens': ['0.8K', '1.0K', '1.1K', '1.3K', '1.4K', '2.9K'],
    'Accuracy (%)': [49.50, 42.50, 44.50, 45.50, 44.50, 29.50]
}
df = pd.DataFrame(data)

# Define the style (using 'TD Test' style for variety)
main_color = 'rgba(255, 127, 14, 1)'  # Orange
bg_color = 'rgba(255, 127, 14, 0.3)'   # Lighter, semi-transparent orange
marker_symbol = 'star'

# Create the figure object
fig = go.Figure()

# Add the background trace (thick, semi-transparent line)
fig.add_trace(go.Scatter(
    x=df["top-k"],
    y=df["Accuracy (%)"],
    mode='lines',
    line=dict(color=bg_color, width=12),
    hoverinfo='none'
))

# Add the foreground trace (thin line with markers)
fig.add_trace(go.Scatter(
    x=df["top-k"],
    y=df["Accuracy (%)"],
    mode='lines+markers',
    name='Accuracy',
    line=dict(color=main_color, width=2),
    marker=dict(
        color=main_color,
        symbol=marker_symbol,
        size=22
    )
))

# Apply the detailed layout and styling
fig.update_layout(
    title=dict(
        text='<b>Ablation: Effect of top-k Exemplar Pruning</b>',
        x=0.5,
        font=dict(size=32)
    ),
    xaxis_title='<b>top-k</b>',
    yaxis_title='<b>Accuracy (%)</b>',
    font=dict(size=28, family="Arial, sans-serif"),
    showlegend=False,
    margin=dict(l=80, r=40, t=80, b=80),
    paper_bgcolor="white",
    plot_bgcolor="white",
)

# Style the X and Y axes
fig.update_xaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(weight='bold')
)
fig.update_yaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(weight='bold')
)

# Save the figure as a static image
fig.write_image("top-k_vs_accuracy.png", scale=3)

fig.show()

# %%
# Set default template for a clean, paper-ready look
pio.templates.default = "plotly_white"

# Data from your table
data = {
    'top-k': [2, 3, 4, 5, 6, 10],
    '# Tokens': ['0.8K', '1.0K', '1.1K', '1.3K', '1.4K', '2.9K'],
    'Accuracy (%)': [49.50, 42.50, 44.50, 45.50, 44.50, 29.50]
}
df = pd.DataFrame(data)

# Convert '# Tokens' from string (e.g., '0.9K') to numeric values
# by removing 'K' and multiplying by 1000.
df['Token Count'] = df['# Tokens'].str.replace('K', '').astype(float) * 1000

# Define the style (using 'TD Val' style for variety)
main_color = 'rgba(44, 160, 44, 1)'   # Green
bg_color = 'rgba(44, 160, 44, 0.3)'   # Lighter, semi-transparent green
marker_symbol = 'pentagon'

# Create the figure object
fig = go.Figure()

# Add the background trace
fig.add_trace(go.Scatter(
    x=df["top-k"],
    y=df["Token Count"],
    mode='lines',
    line=dict(color=bg_color, width=12),
    hoverinfo='none'
))

# Add the foreground trace
fig.add_trace(go.Scatter(
    x=df["top-k"],
    y=df["Token Count"],
    mode='lines+markers',
    name='Token Size',
    line=dict(color=main_color, width=2),
    marker=dict(
        color=main_color,
        symbol=marker_symbol,
        size=22
    )
))

# Apply the detailed layout and styling
fig.update_layout(
    title=dict(
        text='<b>Effect of top-k Pruning on Input Token Size</b>',
        x=0.5,
        font=dict(size=32)
    ),
    xaxis_title='<b>top-k</b>',
    yaxis_title='<b>Number of Tokens</b>',
    font=dict(size=28, family="Arial, sans-serif"),
    showlegend=False,
    margin=dict(l=80, r=40, t=80, b=80),
    paper_bgcolor="white",
    plot_bgcolor="white",
)

# Style the X and Y axes
fig.update_xaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(weight='bold')
)
fig.update_yaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(weight='bold')
)

# Save the figure as a static image
fig.write_image("top-k_vs_tokens.png", scale=3)

fig.show()

# %%
# Set default template for a clean, paper-ready look
pio.templates.default = "plotly_white"

# Data from your table
data = {
    'Selection': ['High-SNR', 'Randomly', 'Shortlisting Centroids'],
    'Accuracy (%)': [39.00, 16.47, 8.63]
}
df = pd.DataFrame(data)

# Sort the data for a clearer presentation
df = df.sort_values(by='Accuracy (%)', ascending=False)

# Define a color palette from your earlier examples
colors = ['rgba(31, 119, 180, 1)', 'rgba(255, 127, 14, 1)', 'rgba(44, 160, 44, 1)']

# Create the bar chart
fig = go.Figure(go.Bar(
    x=df['Selection'],
    y=df['Accuracy (%)'],
    marker_color=colors,
    text=df['Accuracy (%)'],  # Add text labels on bars
    textposition='auto',      # Position the text automatically
    textfont=dict(
        size=26,
        color='white',
        weight='bold',
    )
))

# Apply the detailed layout and styling
fig.update_layout(
    title=dict(
        text='<b>Effect of Different Exemplar Selection Methods</b>',
        x=0.5,
        font=dict(size=32)
    ),
    xaxis_title='<b>Selection Method</b>',
    yaxis_title='<b>Accuracy (%)</b>',
    font=dict(size=22, family="Arial, sans-serif"),
    margin=dict(l=80, r=40, t=80, b=80),
    paper_bgcolor="white",
    plot_bgcolor="white",
)

# Style the X and Y axes
fig.update_xaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    tickfont=dict(weight='bold')
)
fig.update_yaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    tickfont=dict(weight='bold')
)

# Save the figure as a static image
fig.write_image("selection_vs_accuracy.png", scale=3)

fig.show()

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.io as pio
from plotly.subplots import make_subplots

# Set default template for a clean, paper-ready look
pio.templates.default = "plotly_white"

# Data from your table, focusing on the consistent "# Bins = 5" experiment
data = {
    'top-k': [2, 3, 4, 5, 6, 10],
    '# Tokens': ['0.8K', '1.0K', '1.1K', '1.3K', '1.4K', '2.9K'],
    'Accuracy (%)': [49.50, 42.50, 44.50, 45.50, 44.50, 29.50]
}
df = pd.DataFrame(data)

# Convert '# Tokens' from string (e.g., '0.9K') to numeric values
df['Token Count'] = df['# Tokens'].str.replace('K', '').astype(float) * 1000

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Define styles for the two lines
style1 = {
    'color': 'rgba(31, 119, 180, 1)',  # Blue
    'bg_color': 'rgba(31, 119, 180, 0.3)',
    'symbol': 'circle'
}
style2 = {
    'color': 'rgba(255, 127, 14, 1)',  # Orange
    'bg_color': 'rgba(255, 127, 14, 0.3)',
    'symbol': 'star'
}

# --- Accuracy Trace (Left Y-axis) ---
# Background trace
fig.add_trace(go.Scatter(
    x=df["top-k"],
    y=df["Accuracy (%)"],
    mode='lines',
    line=dict(color=style1['bg_color'], width=12),
    hoverinfo='none',
    showlegend=False  # Hide from legend
), secondary_y=False)

# Foreground trace
fig.add_trace(go.Scatter(
    x=df["top-k"],
    y=df["Accuracy (%)"],
    mode='lines+markers',
    name='Accuracy',
    line=dict(color=style1['color'], width=2),
    marker=dict(
        color=style1['color'],
        symbol=style1['symbol'],
        size=22
    )
), secondary_y=False)


# --- Token Size Trace (Right Y-axis) ---
# Background trace
fig.add_trace(go.Scatter(
    x=df["top-k"],
    y=df["Token Count"],
    mode='lines',
    line=dict(color=style2['bg_color'], width=12),
    hoverinfo='none',
    showlegend=False # Hide from legend
), secondary_y=True)

# Foreground trace
fig.add_trace(go.Scatter(
    x=df["top-k"],
    y=df["Token Count"],
    mode='lines+markers',
    name='Token Size',
    line=dict(color=style2['color'], width=2),
    marker=dict(
        color=style2['color'],
        symbol=style2['symbol'],
        size=22
    )
), secondary_y=True)


# --- Layout and Styling ---
fig.update_layout(
    title=dict(
        text='<b>Effect of top-k Pruning on Accuracy and Token Size</b>',
        x=0.5,
        font=dict(size=32)
    ),
    xaxis_title='<b>top-k</b>',
    font=dict(size=28, family="Arial, sans-serif"),
    showlegend=True, # Show legend
    legend=dict(
        orientation="h",
        yanchor="top",
        y=-0.2,
        xanchor="right",
        x=1
    ),
    margin=dict(l=80, r=80, t=80, b=80),
    paper_bgcolor="white",
    plot_bgcolor="white",
)

# Style X and Y axes
fig.update_xaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(weight='bold')
)
fig.update_yaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(weight='bold')
)

# Set y-axis titles
fig.update_yaxes(title_text="<b>Accuracy (%)</b>", secondary_y=False, color=style1['color'])
fig.update_yaxes(title_text="<b>Number of Tokens</b>", secondary_y=True, color=style2['color'])


# Save and show the figure
fig.write_image("top-k_vs_accuracy_and_tokens.png", scale=5)
fig.show()

# %%
# Set default template for a clean, paper-ready look
pio.templates.default = "plotly_white"

# Data from your LaTeX table
data = {
    'top-k': [1, 2, 3, 4, 5, 6, 7],
    'Accuracy (%)': [65.33, 87.00, 94.28, 99.50, 99.83, 99.97, 100.00]
}
df = pd.DataFrame(data)

# Define a style for the plot
main_color = 'rgba(44, 160, 44, 1)'   # Green
bg_color = 'rgba(44, 160, 44, 0.3)'   # Lighter, semi-transparent green
marker_symbol = 'pentagon'

# Create the figure object
fig = go.Figure()

# Add the background trace (thick, semi-transparent line)
fig.add_trace(go.Scatter(
    x=df["top-k"],
    y=df["Accuracy (%)"],
    mode='lines',
    line=dict(color=bg_color, width=12),
    hoverinfo='none'
))

# Add the foreground trace (thin line with markers)
fig.add_trace(go.Scatter(
    x=df["top-k"],
    y=df["Accuracy (%)"],
    mode='lines+markers',
    name='Accuracy',
    line=dict(color=main_color, width=2),
    marker=dict(
        color=main_color,
        symbol=marker_symbol,
        size=22
    )
))

# Apply the detailed layout and styling
fig.update_layout(
    title=dict(
        text='<b>Shortlisting Classifier Accuracy vs. top-k</b>',
        x=0.5,
        font=dict(size=32)
    ),
    xaxis_title='<b>top-k</b>',
    yaxis_title='<b>Accuracy (%)</b>',
    font=dict(size=28, family="Arial, sans-serif"),
    showlegend=False,
    margin=dict(l=80, r=40, t=80, b=80),
    paper_bgcolor="white",
    plot_bgcolor="white",
)

# Style the X and Y axes
fig.update_xaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(weight='bold')
)
fig.update_yaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(weight='bold')
)

# Save the figure as a static image
fig.write_image("shortlisting_accuracy_vs_top_k.png", scale=3)

fig.show()

# %%
# Set default template for a clean, paper-ready look
pio.templates.default = "plotly_white"

# Data from your table
data = {
    '# Bins': [5, 10, 20, 30],
    'Accuracy (%)': [45.50, 39.00, 38.00, 37.00]
}
larger_data = {
    '# Bins': [20, 10, 5],
    'Accuracy (%)': [35.50, 47.50, 40.50]
    }
df = pd.DataFrame(data)
larger_df = pd.DataFrame(larger_data)

# Define the style based on your example code (using 'PN Train' style)
main_color = 'rgba(31, 119, 180, 1)'  # Blue
bg_color = 'rgba(31, 119, 180, 0.3)' # Lighter, semi-transparent blue
marker_symbol = 'circle'

# Create the figure object
fig = go.Figure()

# Add the background trace (thick, semi-transparent line)
fig.add_trace(go.Scatter(
    x=df["# Bins"],
    y=df["Accuracy (%)"],
    mode='lines',
    line=dict(color=bg_color, width=12),
    hoverinfo='none', # Don't show hover info for the background line
    showlegend=False,
))

# Add the foreground trace (thin line with markers)
fig.add_trace(go.Scatter(
    x=df["# Bins"],
    y=df["Accuracy (%)"],
    mode='lines+markers',
    name='Gemini-2.5-Flash',
    line=dict(color=main_color, width=2),
    marker=dict(
        color=main_color,
        symbol=marker_symbol,
        size=22
    ),
))

# Add the background trace (thick, semi-transparent line)
fig.add_trace(go.Scatter(
    x=larger_df["# Bins"],
    y=larger_df["Accuracy (%)"],
    mode='lines',
    line=dict(color=style2['bg_color'], width=12),
    hoverinfo='none',
    showlegend=False
))

# Add the foreground trace (thin line with markers)
fig.add_trace(go.Scatter(
    x=larger_df["# Bins"],
    y=larger_df["Accuracy (%)"],
    mode='lines+markers',
    name='Gemini-2.5-Pro',
    line=dict(color=style2['color'], width=2),
    marker=dict(
        color=style2['color'],
        symbol=style2['symbol'],
        size=22
    )
))

# Apply the detailed layout and styling from your example
fig.update_layout(
    title=dict(
        text='<b>Effect of Number of Bins on Accuracy</b>',
        x=0.5,
        font=dict(size=32)
    ),
    xaxis_title='<b># Bins</b>',
    yaxis_title='<b>Accuracy (%)</b>',
    showlegend=True, # Show legend
    legend=dict(
        orientation="h",
        yanchor="top",
        y=-0.2,
        xanchor="right",
        x=1.05
    ),
    font=dict(size=20, family="Arial, sans-serif"),
    margin=dict(l=80, r=40, t=80, b=80),
    paper_bgcolor="white",
    plot_bgcolor="white",
)

# Style the X and Y axes
fig.update_xaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(size=26, weight='bold')
)
fig.update_yaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(size=26, weight='bold')
)

# Save the figure as a static image
fig.write_image("styled_bins_vs_accuracy.png", scale=3)

fig.show()

# %%
df = pd.read_csv("../exp/results_summary.csv")
column_split = [ r.split(',') for r in df['acc']]
df["#correct"] = [ int(r[0][1:]) for r in column_split ]
df["acc"] = [ float(r[2][:-1])*100 for r in column_split ]
df['dataset'] = df['DATASET_FOLDER']
df['filter'] = df['PREDICTION_SOURCE']
df['use_RAG'] = df['USE_RAG']
df['signal_feature'] = df['FEATURE_TYPE']
df['model'] = df["Model"].astype(str).str.replace("unsloth/", "", regex=False)

df = df[['model', 'dataset', 'filter', 'use_RAG', 'signal_feature', '#correct', 'acc']]
df
# Out:
#                           model        dataset    filter  use_RAG  \
# 0   DeepSeek-R1-Distill-Qwen-7B  unlabeled_10k  centroid     True
# 1   DeepSeek-R1-Distill-Qwen-7B  unlabeled_10k  centroid    False
# 2   DeepSeek-R1-Distill-Qwen-7B  unlabeled_10k  centroid    False
# 3                GLM-4.6V-Flash  unlabeled_10k  centroid    False
# 4   DeepSeek-R1-Distill-Qwen-7B  unlabeled_10k     faiss     True
# 5                GLM-4.6V-Flash  unlabeled_10k     faiss     True
# 6   DeepSeek-R1-Distill-Qwen-7B  unlabeled_10k     faiss     True
# 7                GLM-4.6V-Flash  unlabeled_10k     faiss     True
# 8   DeepSeek-R1-Distill-Qwen-7B  unlabeled_10k     faiss    False
# 9                GLM-4.6V-Flash  unlabeled_10k     faiss    False
# 10  DeepSeek-R1-Distill-Qwen-7B  unlabeled_10k     faiss    False
# 11               GLM-4.6V-Flash  unlabeled_10k     faiss    False
# 12  DeepSeek-R1-Distill-Qwen-7B          -30dB  centroid     True
# ...

# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

pio.templates.default = "plotly_white"

# Map dataset to Distribution
df['Distribution'] = df['dataset'].map({
    'unlabeled_10k': 'In-Dist (unlabeled_10k)',
    '-30dB': 'OOD (-30dB)',
    '-11_-15dB': 'OOD (-11 to -15dB)'
})

# ==========================================
# Plot 1: In-Distribution vs OOD Performance
# ==========================================
fig1 = px.box(df, x='Distribution', y='acc', color='model',
              color_discrete_sequence=['rgba(31, 119, 180, 1)', 'rgba(255, 127, 14, 1)'])

fig1.update_layout(
    title=dict(
        text='<b>LLM as a Classifier: In-Distribution vs Out-of-Distribution</b>',
        x=0.5,
        font=dict(size=28)
    ),
    xaxis_title='<b>Dataset Environment</b>',
    yaxis_title='<b>Accuracy (%)</b>',
    font=dict(size=22, family="Arial, sans-serif"),
    margin=dict(l=80, r=40, t=80, b=80),
    paper_bgcolor="white",
    plot_bgcolor="white",
    legend=dict(
        title='<b>Model</b>',
        orientation="h",
        yanchor="top",
        y=-0.3,
        xanchor="center",
        x=0.5
    )
)

fig1.update_xaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(weight='bold')
)
fig1.update_yaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(weight='bold')
    
)

fig1.write_image("1_InDist_vs_OOD.png", scale=3, width=1200, height=800)
fig1.show()

# %%
# ==========================================
# Plot 2: Impact of Examples (RAG vs No RAG)
# ==========================================
agg_df2 = df.groupby(['use_RAG', 'Distribution'])['acc'].agg(['mean', 'std']).reset_index()
agg_df2['use_RAG'] = agg_df2['use_RAG'].astype(str)

fig2 = px.bar(agg_df2, x='Distribution', y='mean', color='use_RAG', barmode='group',
              error_y='std',
              color_discrete_sequence=['rgba(31, 119, 180, 1)', 'rgba(255, 127, 14, 1)'])

fig2.update_layout(
    title=dict(
        text='<b>Impact of Examples: RAG (True) vs Fixed Selection (False)</b>',
        x=0.5,
        font=dict(size=28)
    ),
    xaxis_title='<b>Dataset Environment</b>',
    yaxis_title='<b>Accuracy (%)</b>',
    font=dict(size=22, family="Arial, sans-serif"),
    margin=dict(l=80, r=40, t=80, b=80),
    paper_bgcolor="white",
    plot_bgcolor="white",
    legend=dict(
        title='<b>Use RAG?</b>',
        orientation="h",
        yanchor="top",
        y=-0.3,
        xanchor="center",
        x=0.5
    )
)

fig2.update_xaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(weight='bold')
)
fig2.update_yaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(weight='bold')
)

fig2.write_image("2_RAG_Impact.png", scale=3, width=1200, height=800)
fig2.show()

# %%
# ==========================================
# Plot 3: Filtering Strategy (FAISS vs Centroid)
# ==========================================
# Filter to only look at rows where RAG was actually used
rag_df = df[df['use_RAG'] == True]
agg_df3 = rag_df.groupby(['filter', 'Distribution'])['acc'].agg(['mean', 'std']).reset_index()

fig3 = px.bar(agg_df3, x='Distribution', y='mean', color='filter', barmode='group',
              error_y='std',
              color_discrete_sequence=['rgba(31, 119, 180, 1)', 'rgba(255, 127, 14, 1)', 'rgba(44, 160, 44, 1)'])

fig3.update_layout(
    title=dict(
        text='<b>Impact of Filtering Strategy (FAISS vs Centroid with RAG)</b>',
        x=0.5,
        font=dict(size=28)
    ),
    xaxis_title='<b>Environment</b>',
    yaxis_title='<b>Accuracy (%)</b>',
    font=dict(size=22, family="Arial, sans-serif"),
    margin=dict(l=80, r=40, t=80, b=80),
    paper_bgcolor="white",
    plot_bgcolor="white",
    legend=dict(
        title='<b>Filtering Method</b>',
        orientation="h",
        yanchor="top",
        y=-0.3,
        xanchor="center",
        x=0.5
    )
)

fig3.update_xaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(weight='bold')
)
fig3.update_yaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(weight='bold')
)

fig3.write_image("3_Filtering_Strategy.png", scale=3, width=1200, height=800)

fig3.show()

# %%
# ==========================================
# Plot 4: Feature Comparison (Embeddings vs Stats)
# ==========================================
agg_df4 = df.groupby(['signal_feature', 'Distribution'])['acc'].agg(['mean', 'std']).reset_index()

fig4 = px.bar(agg_df4, x='Distribution', y='mean', color='signal_feature', barmode='group',
              error_y='std',
              color_discrete_sequence=['rgba(31, 119, 180, 1)', 'rgba(255, 127, 14, 1)', 'rgba(44, 160, 44, 1)'])

fig4.update_layout(
    title=dict(
        text='<b>Feature Representation: Embeddings vs Statistical Features</b>',
        x=0.5,
        font=dict(size=28)
    ),
    xaxis_title='<b>Environment</b>',
    yaxis_title='<b>Accuracy (%)</b>',
    font=dict(size=22, family="Arial, sans-serif"),
    margin=dict(l=80, r=40, t=80, b=80),
    paper_bgcolor="white",
    plot_bgcolor="white",
    legend=dict(
        title='<b>Feature Type</b>',
        orientation="h",
        yanchor="top",
        y=-0.3,
        xanchor="center",
        x=0.5
    )
)

fig4.update_xaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(weight='bold')
)
fig4.update_yaxes(
    showline=True,
    linewidth=2,
    linecolor='black',
    mirror=True,
    ticks="outside",
    tickwidth=2,
    tickfont=dict(weight='bold')
)

fig4.write_image("4_Feature_Comparison.png", scale=3, width=1200, height=800)

fig4.show()

# %%
# ==========================================
# Print text summaries for your talking points
# ==========================================
print("=== Accuracies by Distribution ===")
print(df.groupby('Distribution')['acc'].mean().round(3))

print("\n=== Accuracies by RAG ===")
print(df.groupby(['Distribution', 'use_RAG'])['acc'].mean().round(3))

print("\n=== Accuracies by Retrieval (when RAG is used) ===")
print(rag_df.groupby('filter')['acc'].mean().round(3))

print("\n=== Accuracies by Feature Type ===")
print(df.groupby('signal_feature')['acc'].mean().round(3))
# Out:
# === Accuracies by Distribution ===
# Distribution
# In-Dist (unlabeled_10k)    55.333
# OOD (-11 to -15dB)         54.682
# OOD (-30dB)                 6.500
# Name: acc, dtype: float64
#
# === Accuracies by RAG ===
# Distribution             use_RAG
# In-Dist (unlabeled_10k)  False      54.643
#                          True       56.300
# OOD (-11 to -15dB)       False      53.500
#                          True       56.100
# OOD (-30dB)              False       7.000
#                          True        6.200
# Name: acc, dtype: float64
#
# === Accuracies by Retrieval (when RAG is used) ===
# filter
# centroid    26.786
# faiss       50.688
# Name: acc, dtype: float64
#
# === Accuracies by Feature Type ===
# signal_feature
# embeddings    47.375
# stats         37.300
# Name: acc, dtype: float64
